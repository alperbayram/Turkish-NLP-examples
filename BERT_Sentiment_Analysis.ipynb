# %% [markdown]
# <a href="https://colab.research.google.com/github/alperbayram/Turkish-NLP-examples/blob/main/BERT_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.6.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)

# %%
import os
import pandas as pd
from warnings import filterwarnings
filterwarnings('ignore')
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer, AutoModelForSequenceClassification
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from pandas import Series, DataFrame
from google.colab import drive

# %%
from pandas import Series, DataFrame

# %%
data_path =  "/resource/"

try:
    drive.mount('/content/drive')
    data_path = "/content/drive/My Drive/resource/"

except:
    print("You are not working in Colab at the moment :(")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(data_path + 'TrkceTwitdata.csv')
df_Tweets = pd.DataFrame(df)

# %%
df_Tweets.head()
# Out:
#                                              Tweets;
# 0   sayın cumhurbaşkanım turizm için ertelendiğin...
# 1   bir kere ya bir kere gencinizi dinleyin biz y...
# 2  o kadar çok mağduruz ki neye üzüleceğime şaşır...
# 3   bu sınav tarihini değiştirirken pedaloglara v...
# 4        turizm yılı gençlik geleceğinizi kurtarır ;

# %%
df.columns = ['Tweets']

# %%
model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased")

# %%
analysis = pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)

# %%
code_to_label={
 'negative': 'negatif',
 'positive': 'pozitif',
    'notr': 'notr'
    
}

# %%
df_Tweets.Tweets[50]
# Out:
# ' aydogan dün turizm bakanı tiyatroların geleceği konusunda önemsiz açıklamalar yaptı ;'

# %%
analysis(df_Tweets.Tweets[50])
# Out:
# [{'label': 'negative', 'score': 0.9921867847442627}]

# %%
#df_Tweetler.shape[0]
orders = df_Tweets.Tweets.value_counts().count()
print('Tweet sayısı :',orders)
# Out:
# Tweet sayısı : 2017

# %%
Tweet = list(df_Tweets.Tweets)

# %%
Tweet
# Out:
# [' sayın cumhurbaşkanım turizm için ertelendiğini biliyoruz fakat illa ki uygun zaman vardır lütfen sağlığımız ve psikol ;',
#  ' bir kere ya bir kere gencinizi dinleyin biz yanlış bir şey demiyoruz ki herkes için doğrusunu söylüyoruz ;',
#  'o kadar çok mağduruz ki neye üzüleceğime şaşırdım hiçbir yerden destek alamıyoruz yasak var dışarı çıkamıyoruz   ;',
#  ' bu sınav tarihini değiştirirken pedaloglara ve psikologlara danışıldı mı tabiki hayır bu kararı kim verdi turizm bakanI ;',
#  ' turizm yılı gençlik geleceğinizi kurtarır ;',
#  ' sizden kıyak isteyen yok turizm yüzünden yediğiniz hakkımızı geri verin haftadır milletün planı alt üst oldu zaten  ;',
#  ' bunu söylemek bile üzüyor ama turizm bu kadar değerliyse sınavı ağustos sonu veya eylül gibi alsanız da olur ;',
#  ' mayıs ı gençlere armağan eden ulu önder mustafa kemal atatürk ten turizm için gençlerin canını ve geleceğini hiçe say ;',
#  ' turizm mi önemli ülkenin geleceği olan bizler mi ;',
#  ' erteleyin son iftarlarimizi rahat yapalım sağlık bakanı riskli diyor turizm bakanın olmayan beynine sokayim ;',
#  ' turizm mi önemli cidden ;',
#  ' hem turizm hemde bizler önemliyiz o yüzden sınavı daha ileri bir tarihe erteleyin ki iki tarafın gönlü olsun ;',
#  ' mağdur olmasın diye tek bir ögrenci için tren durağı işleten japonya turizm geliri için milyonlarca ögrencisini hiçe sayan ülkem;',
#  ' sınav eylül de olabilirdi aileler bu uzun maratondan bunalıp çocuklarına nefes aldırmak için tatile çıkabilirlerdi ;',
#  ' turizm temmuz içinse ağustos eylule alın sınavı ;',
#  ' sınavı öne almadan önce maskelerin ve dezenfektanların bulaşmayı önleme de yetersiz olduğunu o yüzden evlerden çıkmamamız gerektiğini ne zaman anlayacaksınız ;',
#  ' dünyaca ünlü turizm merkezi uzungöl de kovid sessizliği ;',
#  ' diyanet milyar liralık harcama ile bakanlığı geride bıraktı cumhuriyet  yer alan habere göre diyanet aylık harcaması ;',
#  ' sayın erteleyin ki bayram olsun turizm gençlikten önemli değildir ;',
#  ' geçen gün turizm bakanı olayında reise had bildirmeye çalışan saçma tavırlar içinde olan birkaç hesap vardı sinirlendim ;',
#  ' bakanı mehmet nuri ersoy  istanbul  fethini işgal olarak nitelendirmesi türk milletince kabul edilecek mi ;',
#  'hem turizm hemde bizler önemliyiz o yüzden sınavı daha ileri bir tarihe erteleyin  iki tarafın gönlü olsun ;',
#  ' trabzon  turizm sektörünün temsilcileri ile biraraya geldik pandemi  turizm sektörüne etkileri ile coronavirü ;',
#  ' kurum yerli ve yabancı turistler için önemli bir turizm merkezi olan ilçemizin çehresini de değiştirecek;',
#  ' samet sayın cumhurbaşkanım erteleyinki bayram olsun turizm gençlikten önemli değildir ;',
#  'dedi ve yks tarihini turizm için öne çekti işte ;',
#  ' para bu kadar önemliyse gençliğin sağlığından adaylar bir kere daha tl versin bari turizm için ertelemenize gerek kalmaz ;',
#  'sizden kıyak isteyen yok turizm yüzünden yediğiniz hakkımızı geri verin haftadır milletün planı alt üst oldu ;',
#  'bugün saat nejla kurul ve eğitimsen şb bşk yurttaş yıldırım ile giderek büyüyen eğitim sorunlarını konuşacağız;',
#  ' gercekten niye kimse cikip aciklama yapmiyor bari aciklama yapin sundan ertelemiyoruz turizm bi aciklayin ;',
#  ' biz gençlerin hayallerini turizm için satmak yerine bize bırakacağınız geleceği güzelleştirebilmemiz için iş yapın;',
#  ' turizm bakanından daha değerli olduğumuzu bu günde gösterin bize ;',
#  ' çocuklarımızın geleceğini psikolojisini kaç paraya sattınız bu kadar öğrenci sizin turizm şirketi sahibi bakanınızın cebini doldurmak içinmi var ;',
#  ' keşke bize turizm sizden önemlidir diye açıklama yapsanız en azından dürüst olursunuz ;',
#  ' siz bilirsiniz ama benim bir fikrim var sınavı eylül ayına alın ne turizm zarar görsün ne egitim ;',
#  ' hiçbir ülke turizm geliri için gençliğini ve geleceğini satmaz ;',
#  'bu sınav tarihini değiştirirken pedaloglara ve psikologlara danışıldı mı tabiki hayır bu kararı kim verdi turizm ;',
#  ' turizm yokluğundan korkuyorsanız erteleyin ağustosa aytden çıkınca dağıtın herkese bayrak zafer bayramını kutlayalım ;',
#  ' ben turizm okudum ondan da bi bok olmuyor arkadaşlar sadece derste rakı şarap falan içip alkollü içecekler hakkında konuşuluyor;',
#  ' çocuklarımız turizm gelirine kurban edilemez ;',
#  ' hayır ama şuan  en sağlıklısı bu olacak ve diyoruz ki virüs tehlikesi geçene kadar olsun beklesinler bi ;',
#  ' bu çıkarcı düşüncelerinizle bu çocukları boğamayacaksınız gençleri yakıyorsunuz turizm iyi olmuş kime ne ;',
#  '  başkanı mehmet şahin neden dillendirmiyor bu turizm esnaflarının dükkan kiralarını ;',
#  ' nisan  üzerinde ürüne ilave gümrük vergisi gelmişti bugün  pek çok üründe gümrük vergisi artırıldı ben ;',
#  ' kktc açısından hem iyi bir gelişme hem de büyük başarı konu türkiye  girişimleriyle mümkünse dsö  tescil ettiri ;',
#  ' bekliyoruz serik  belediye başkanına rüşveti kimin verdiği ile ilgili turizm bakanının açıklamasını ;',
#  'covid pandemisinde kongre ve etkinliklere yaklaşımımız anketibsektörün nabzını birlikte tutalım   ;',
#  '  turizm  hizmetlisine el öptürüp bahşiş verirken böyle görgüsüz ve insanlıktan çıkmış kişileri cezalandırın ;',
#  ' olmadı öğrenciye ait tek cümle kurmadı çaydan bahsetti cumhur ittifakı dedi fetö dedi ama milyonlarca ögrenciyi turizme kurban etti;',
#  ' uzmanlar yanıtladı turizm sektörü ve taşımacılık pandemiden sonra nasıl değişecek ;',
#  ' aydogan dün turizm bakanı tiyatroların geleceği konusunda önemsiz açıklamalar yaptı ;',
#  ' tami tamina senedir kicimi yirtiyorum sesimi duyurabilmek icin yuzlerce kez cimer e yazdim rte a mail fax gönderdim   ;',
#  ' uzun yıllar tarihi dokusunu korumuş olan ceyhan köprüsü taş köprü çevresine yapmayı planladığımız kılavuzlu millet bahçesini istemiyoruz ;',
#  ' turizm için eğitimi feda etmişler sen daha ne dersin neyden bahsedersin ;',
#  ' nisan da in üzerinde ürüne ilave gümrük vergisi gelmişti bugün de pek çok üründe gümrük vergisi artırıldı ;',
#  ' bu öğrencilerin sesini duyun artık turizm mi daha önemli yoksa insan canı mı ;',
#  ' bu ogrencilerin ailelerinden aldıginiz yardimlar yetmedi mi de turizm ugruna geleceklerini yakiyosunuz ;',
#  ' turizm şirketleri insan sağlığından önemli değildir ;',
#  ' antalya da turizm ayağına yasakları kaldırdınız sokaklar full;',
#  ' soruları turizm bakanı hazırlasın ;',
#  'türk gençleri olarak bu ülkede söz sahibi olmadığımızı ve turizm sektörünün yarının büyükleri olan bizden ağır bastı ;',
#  'en baştan beri bunu söylüyorum ama gidilecek bölgeler kısıtlı olmalı turizm alanlarına giriş engellenmeli sadece ;',
#  'turizm dekanları paneli canlı yayınını izleyemeyenler için link aşağıda yer almaktadır ;',
#  'her ne kadar bu isteklerde bulunan gençlerin bazılarının art niyetli ve nefsani duygularına katılmasam da alınan karar yanlış;',
#  ' bizim savaştan önce eğitim diyen bi atamız vardı şimdi eğitimden önce turizm diyen yönetim var;',
#  ' bütün umudum gençliktedir bu söz ne kadar anlamlı ve doğru değil mi bu söz tam da bu sene unutuldu ;',
#  'eğitim kararlarını turizm bakanı nın aldığı nerede görüldü ;',
#  ' lan tamam bari ağustosta yapın o zaman turizm de etkilenmez eylülde de tercihleri yaparız öğrenci düşmanı mısınız ya   ;',
#  ' amaç turizmi değil şirketi olan turizm bakanını kurtarma çabasıdır ;',
#  ' sanki temmuz ayında özellikle turizm beldelerinde ki işletmeler rahatlayacaktır;',
#  'yks siyasi iktidar tarafından turizm sezonu gerekçe gösterilerek ay öne çekildi ;',
#  ' beyefendi virüs varken sırf turizm için sınavı öne çekmek mantıksızlık   ;',
#  ' dünya turizm örgütü uluslararası turizmde bu yıl milyon ila milyar turist kaybı yaşanacak dedi;',
#  'turkiye sehir olarak antalya sektor olarakcilik bu viruse karsi her anlamda en hazir olandir   ;',
#  ' imar planı onaylandı koruma amaçlı imar planı kültür ve turizm bakanlığı tarafından onaylandı   ;',
#  ' turizm bakani ösym başkanı milli egitim bakanı ve özellikle cumhurbaşkani sizler özellikle bu karede net milyon twitle cevap vereceğiz ;',
#  ' bu çıkarcı düşüncelerinizle bu çocukları boğamayacaksınız gençleri yakıyorsunuz turizm iyi olmuş ;',
#  ' yazıklar olsun ya daha ne denilebilir ki çay kadar turizm kadar değerimiz yokmuş ;',
#  ' hatırlatma için teşekkür kim bilir daha neler var doğu karadeniz de bunu şimdi görüyorum bölge gelecek için ekoturizm ;',
#  ' ne okudun turizm senin oraya gelim de bana bi rus ayarla ;',
#  ' en baştan beri bunu söylüyorum ama gidilecek bölgeler kısıtlı olmalı turizm alanlarına giriş engellenmeli ;',
#  'avmler açılsın berberler güzellik salonları açılsın sınavlar öne çekilip öğrencilerin psikolojileri altüst edilsin ;',
#  ' dogu avm çalışanları aktiftiler bir şekilde kısa ödenek alabiliyorlar   ;',
#  ' turizmden açılsa da beklentimiz çok yüksek olmamalı biz gelecek turistten pcr talep etsek de turist gelirken acaba gidip yaparmı ;',
#  ' ziya selçuk diyor yks bizimle ilgili değil yök ortalıkta yok bize turizm bakanı bakıyor ;',
#  ' şile yi hem istanbul hem de türkiye ölçeğinde turizm destinasyonu haline getirmek en büyük arzumuz ;',
#  'istanbul il kültür ve turizm müdürlüğümüzün ev sahipliğinde gerçekleşecek olan program sosyal medya hesaplarımızda;',
#  ' bana bak ösym vallahi çocukları bi salarım dışarıya virüs mirüs hak getire ondan sonra sınavlarda sorarsın   ;',
#  ' turizm bakanınında bu kadar üzerine gelmeyin sonuçta etstur un sahibi ve milletten daha önemli işleri var ;',
#  ' cahil yandaş ve yalanci adana daki zaten adı üstünde sahra hastanesi olduğu için acele alçıpan panellerle yapıldı;',
#  'turizm bölgesi ama senelerdir turizm yatırımından vazgeçtim altyapısı bile tam yapılmadı havaalanına sahil yolu açılmadı ;',
#  'hep beraber ya gidiyoruz japonya turizm ajansı temmuz ayı itibariyle ülkeyi ziyaret edecek olan turistlere promosyon verecekmiş ;',
#  ' bence bu yıl rusya dan turist beklentisini yükseltmeyelim bahanesiyle vatandaşlarının yurt dışına çıkışını teşvik etmeyin;',
#  'yks nin yarın yapılması için milyon tweet atalım bugün turizm bizden değerlidir önü açılsın ;',
#  ' bizim turizm ve hizmet sektörü istihdamın dan fazlasını karşılıyor çok büyük bir rakam mecburuz ;',
#  ' şanlıurfa daki göbeklitepe the national geographic in mutlaka ziyaret edilmesi gereken yerler listesinde;',
#  'bakan çavuşoğlu türkiye nin dış politikasını atatürk ün yurtta sulh cihanda sulh anlayışıyla sürdürüyoruz ;',
#  'birazda turizm esnafının yanında olsanız çok seviniriz ;',
#  'ingiltere almanya fransa ile turizm dörtlü toplantısı yaptık bakan çavuşoğlu açıkladı;',
#  'uçuş iptalleri oteller için iyi haber değil rusya ve almanya hava koridoru açılmadığı sürece turizm sezonu bitik;',
#  'italya dışişleri bakanı di maio haziran avrupa da turizm için kurtuluş günüdür dedi;',
#  ' japonya turizm ajansı temmuz ayı itibariyle ülkeyi ziyaret edecek olan turistlerin harcamalarının yarısının devlet tarafından karşılanacağını bildirdi ;',
#  ' turkey kültür ve turizm bakan yardımcımız sn tr ramazan da yaklaşık ülkeye türkiye nin yardımlarını ulaştı ;',
#  'ingiltere almanya fransa ile turizm dörtlü toplantısı yaptık bakan çavuşoğlu açıkladı ;',
#  'almanya ülkeye seyahat yasağını kaldırıyor ilk listede türkiye yok    ;',
#  ' döviz ve altın alımına vergi koyup valör getiren işsizlik sayısı artan covid yüzünden tabii ki ;',
#  ' ilerleyen günlerde ele alınabilecekler konulardan bir tanesi de turizm pandemi sonrası ekolojik turizm ;',
#  ' arabası var liralık yardımın peşinden koşturuyor ;',
#  ' rusya da covid vakaları hızla artıyor turizm sezonu açılınca rusya dan  hiç turist alınmamalı  ;',
#  ' koronavirüs nedeniyle turizm sektörü sıkıntılı günler geçirse de yavaş yavaş normalleşme adımları atılmaya başlanıyor;',
#  ' rusya devleti kendi vatandaşlarına ülkeyi terk etmeyin tatil için rusya içinde kalın ulaşım ve fiyat konularında tüm kolaylıklar sağlanacağı garantisini verdi;',
#  'italya dışişleri bakanı haziran avrupa da turizm için kurtuluş günü olacağını idda etti;',
#  ' klaus schmidt den sonraki döneme ait bilgilere tam olarak hakim değiliz  ;',
#  ' turizm bakanlığının israil in yeni turizm bakanı ile görüşmesi halinde türkiye yi de seyahat edilebileceklerini bildirdi ;',
#  ' bizleri ya salin ya öldürün yeter bu iskence ceza herkese bi kolaylik var bize neden yok ;',
#  ' uçak şirketi ve ets tur un sahibi turizm bakanı medipol hastaneleri nin sahibi sağlık bakanı maya okullarının sahibi meb bakanı ne güzel şirket değilmi;',
#  ' turizm bakanlığının manavgat kızılağaç kum mevki bölgesindeki yaptığı planlamayla kentin sahil ile bağlantısı kapatılıyor ;',
#  ' turizm canlansin diye her turlu kolayligi sagliyorsun bizleri de düşünün ;',
#  ' hiçbir şey olmasa da kesin bir şeyler olmuş sandıklar bir daha sayılmalı turizm canlanmalı ;',
#  ' pandemi en başta hizmet sektörünü çok ağır bir şekilde vurdu  ;',
#  'pamukkale turizm seferleri başlıyor ;',
#  ' ilgili belediyelerin sosyal medya yönetimleri sıfır türkçe bilgileri zaten yok ha ;',
#  ' haziran avrupa da turizm için kurtuluş günü ;',
#  ' manavgat a golf sahası değil yat limani ve yat çekek ve imalati ihtisas edilmeli artık;',
#  'alanya da turizm için kötü haber ;',
#  'son yılda türkiye tarihinin ve dünyanın en iyi ulaşım başarısına en iyi turizm başarısına sahip olabiliriz;',
#  ' ktv de türkiye nin turizm geleceğini konuşuyoruz yoğun istek üzerine tekrarı yayınlanıyor bence kaçırmayın ;',
#  ' imamoglu başkan seni listeye almamışlar kültür ve turizm bakanlığı ve tatil en çok sana yakışıyor   ;',
#  'kapadokya da ki aziz jean kilisesi çok şey anlatıyor  ;',
#  'fıjet başkanı tijani haddad ile uluslararası turizm ve covid sohbetileri ;',
#  ' zumi için bu süreç bir şans doğa öko ve slow turizm gibi ;',
#  'nasıl önemi yok ama lafla peynir gemisi yürüyebilecek mi maliyetlere etkisi ne olacak   ;',
#  'büyükşehir den turizm atağı ;',
#  ' turizm patlaması yaşanacak kesin şaka lan şaka ne patlaması yandaş firma restorasyon cukkası kaldıracak sadece ;',
#  ' haber kanallarında plajlar oteller tüm ihtişamıyla gösteriliyor ancak o ihtişamı yaratanların ne adını biliyorlar ne de emeğini;',
#  'havayolu ve turizm şirket hisseleri tavan yaptı;',
#  'koronavirüs nedeniyle turizm sektörü sıkıntılı günler geçirse de yavaş yavaş normalleşme adımları atılmaya başlandı ;',
#  'ortamlarda eskort kızları doldurup grup seks yapan ama twitter da dinci rolü yapan siyasilerin varlığından yeni haberdar olan insanları görüyorum;',
#  'muhteşem erciyes ve turizm merkezi kayseri erciyesimizin bulutlarla dansı ;',
#  'ulaştırma ve altyapı bakanı adil karaismailoğlu yeni tip koronavirüs kovid salgını nedeniyle mart ayında durdurulan uçak seferlerinin haziran da yeniden başlayacağını bildirdi   ;',
#  ' milli park ve tabiat parkı haziran da ziyarete açılacak  ;',
#  ' selamlar pazartesi plajlar halka açılıyorşu an bitez halk plajındayım belediye olarak hiçbir hazırlık göremedim kumsal ot çöp pislik içindebir günde sihirli değnek mi varfotoğraf paylaşmaya utandım ;',
#  'sektör temsilcilerinden turizm bakanlığına turist bilgilendirme çağrısı  ;',
#  'sertifikasyonlu turizm tesislerinde pandemiden uzak güvenli ortam sağlanacak dünyada ilk kez yapılan bu sistem çerçevesinde konuklarımızı ağırlayıp salimen ülkelerine göndereceğiz bakan yardımcımızın röportajı ;',
#  ' haziran pazartesi günün den itibaren yunanistan vize başvuruları izmir den kabul edilmeye başlıyor seyahat tarihleri ağustos den sonrası için planlanmalı  ;',
#  'postcovid için kayıplara değil fırsatlara odaklanmak turizm in sadece gezmek görmek olmadığı çok daha kapsamlı bir ifadeyle ziyaretçi ekonomisi olduğu ve ekonomik sosyal kültürel hayatımızda derin izlerinin bulunduğu bilinci yerleşti sektörün bunu değerlendirmesi  lazım;',
#  'türk hava yolları haziran da bazı yurtdışı seferlerine yeniden başlayacak bu ülkelerden bir tanesi çin  ;',
#  'alanyali turizmciler sertifika için ne kadar ödeyecek  ;',
#  'turizm rus turistlerin tercihi yine türkiye rus tatilcilerin turizm ajansının sitesinde bu ay yaptıkları tatil aramalarında yüzde lük payla türkiye açık ara birinci oldu ;',
#  'türkiye kaldığı yerden devam ediyor başarıyla geride bırakılan pandemi sürecinden sonra turizm sektörü yeniden başlıyor müze ve ören yerlerimiz sizleri bekliyor ;',
#  'vangölü güneyi dağları doğa turizmine yönelik çok farklı alternatifler sunuyor demedi demeyin  ;',
#  'rusya dan turizmciyi sevindiren haber ;',
#  'tui temmuz a kadar yurt dışına turist götürmeyi erteledi;',
#  'yunanistan haziran da turizme açılıyor açıklanan ülkelik listede türkiye hariç tüm komşular için ülkeye giriş izni var ;',
#  'ruslar tatil planı yapıyor türkiye açık ara birinci   ;',
#  ' gökçeada imroz merkez de haziran da açılıyor haftasonu turizm sezonu açıldı ;',
#  'covid virüsü kaynaklı salgının şehrimizin turizmi üzerinde yarattığı olumsuzlukları minimize etmek ve bir yol haritası belirlemek üzere valimiz büyükşehir belediye başkanımız milletvekillerimiz ve elbette turizm temsilcilerimizle çok verimli bir toplantı gerçekleştirdik ;',
#  'güzelliğine güzellik katacak elazığ ın teşekkürler elazığ ;',
#  'covid sürecinden sonra türkiye saglık turizm konusunda ciddi adımlar atmalı son dönemde büyük bir sınavı atlattık turizm gelirlerinin azalacağı dönemde çok ciddi bir katkı sağlayabilir turist başı harcama ortalama seviyesinde sağlık turizmi ile cok artabilir ;',
#  ' mavi bayrakta türkiye lideri ;',
#  'şifalı sularıyla ünlü zenginlerin uğrak yeri olan turizm köyü satılığa çıkarıldı;',
#  'yunanistan türk turist kabul etmiyormuş e gasp ettikleri ege adalarına mültecileri yerleştirseler bari ;',
#  'istanbul un fethi nin yılı kutlu aziz şehitlerimizin mekanı cennet olsun ;',
#  'yapılan araştırmalara göre rus turistlerin yüzde ı türkiye de tatil yapmayı planlıyor  ;',
#  'yunanistan dan hızlı turizm hamlesi yunanistan haziran dan itibaren ülkeden turist kabul edeceğini açıkladı liste temmuzda yenilenecekmiş açıklanan ülkeler arasında ise komşu türkiye yer almıyor neden ;',
#  'rusya dan rus turiste türkiye yolunu açan açıklama antalya ses gazetesi   ;',
#  'turizm sonunda açılıyor mutluyum mutlu olun turizm;',
#  'mardin de türbinli rüzgar santrali kurulacak;',
#  'sayın bakan albayrak yeni eko pakette turizm destek açıklaması var turizm için özel krediler açıklanacak vatandaşa ;',
#  'trip com grubu yılının ilk üç ayına ait finansal verileri basınla paylaştı;',
#  'türkiye büyük fırsatları kaçırıyor gibi geliyor bu aralar maske satışına kısıtlama koyulmuş büyük ticari gelir kaçırılmıştır tr tekstil sektörü içeri ve dışarıyı besleyecek kapasitededir turizm konusunda da hala öncelik verilecek ülkeler açıklanmadı ölüm ve vaka sayıları;',
#  'bir kadına saldırmışlardı mahalleli tedirgin sokak köpekleri dehşet saçıyor burası yenişehir palmiye ve lifa siteleri civarı ;',
#  'turizmde yaşanan daralmanın önüne geçmek için alternatif pazar kanalları yaratılmalı;',
#  'mahalle sakinlerinden belediyeye ve doğalgaz firmasına doğalgaz tepkisi;',
#  'turizm sezonu açılış belirsizliği türk turizminini vurabilir dogrusu ;',
#  'bodrum modern otogarına kavuşuyor;',
#  'bugün çok mutlu olmalıyız çünkü güvercin adamızın kalesi unesco dünya mirası geçici listesinde ;',
#  'bu sezon dan umudunu kesen tek ben miyim  ;',
#  'tarihi ankara kalesi sokaklari hayat bulacak ;',
#  'görünmeyen inciraltı ndan turizm bakanına davet var ;',
#  'easyjet dün yaptığı basın açıklamasında covid krizi nedeniyle düşen talep neticesinde maliyet önlemi olarak mevcut filosunda ve işgücünde tasarrufa gideceğini duyurdu ;',
#  'alanya turistik işletmeciler derneği başkanı burhan sili sağlık ve hijyen standartları misafirlerimizin tatil seçiminde eskisinden daha fazla önem taşıyacak dedi ;',
#  'katid otellere hijyen eğitimi verecek;',
#  'turizm i açalım en azından yerli turist gelsin diyoruzda kimin tatil için maddi manevi gücü kaldı yerli aşı ve ilaç bulma işine yüklenelim şimdilik mesafe maske musluk tek çözüm aşı ;',
#  'baraj gölündeki minareye kayıkla ulaşıyorlar;',
#  'avrupa birligi sene sonuna kadar ulke ab ulkeleri disinda diger ulkelere cikisi yasakladi avrupadan turist bekleyen isletmeler bu sene iflasin esigindeler avrupa ulkeleri turizm gelirlerini bu yasakla tedavi edicek;',
#  'ilk sağlıklı turizm belgesi antalya ya verildi ;',
#  'matt hancock ingilizlerin yurt dışına tatile gidebileceklerini duyurdu şimdi türkiye yunanistan italya ispanya turist kapma savaşları başlayacak elini çabuk tutan kazanır  ;',
#  'en çok turistin geldiği ülkeleri gösteren harita turkiye  ;',
#  'turizm esnafıyım vergi afı bekliyorum hacizlerin kaldırılması bize nefes aldırır boğuluyoruzz;',
#  'fitness salonları haziran dan itibaren sosyal mesafe ve triaj kurallarına uygun olarak açılacak öncelikli olarak ağırlık malzemeleri ardından aerobik bölümü hizmete açılacak;',
#  'turizm işçileri yunanistan da ayaklanmış turizm bu sene kayıp ;',
#  'çeşme otelcileri türob a üye oldu;',
#  ' şehirlerarası seyahatlerde dilekçe gerekmiyecek açık havada temas gerektirmeyen spor yarışmaları seyircisiz yapılacak;',
#  'türkiye ve dünya turizmi hakkında kilit bilgiler içeren güzel bir yazı olmuş ;',
#  'gurur duyduğumuz bir güncellemeyi sizlerle paylaşmak isterim turizm iyileşeceğiz;',
#  'cumhurbaşkanı recep tayyip erdoğan kabine toplantısı sonrası yaptığı açıklamayla ilde uygulanan şehirlerarası seyahat yasağının haziran itibariyle kaldırılacağını duyurdu;',
#  'avrupa nın en büyük tur operatörlerinden tui nin britanya kolu tui uk tatil operasyonlarını temmuz a kadar ertelediğini ve haziran a kadar tüm rezervasyonları iptal ettiğini duyurdu;',
#  'turizm tuzu kuru olanlarda hep aynı laf aman normalleşelim turizm e bir şey olmasın diye dalga geçiyorlar ama biz turizmciler aydır çalışmıyoruz yani cebimize kuruş girmiyor;',
#  'gökyüzünden mardine yükseliyoruz ;',
#  'konyaaltı sahilinde sosyal mesafeli tatil düzenlemesi ;',
#  'kültür ve turizm bakanı ersoy otellerin yüzde sini açabilirsek iyi olacağını düşünüyorum  ;',
#  'urfa erkeği milattan önce neyse milattan sonra da odur uzanıp ense yapmak ruhumuzda var ;',
#  'şehirlerarası seyahat sınırlaması kaldırılıyor ;',
#  'cumhurbaşkanı erdoğan plajlar milli parklar ve bahçeler belirlenen kurallar dahilinde hazarin itibariyle faaliyet geçecek ;',
#  'vanın kimliği turizm olsun yüzlerce turistik mekanımız var bir yerden başlayalım    samimiyetinizi gösterin ;',
#  'türk hava yolları bugün kamuoyu aydınlatma platformu na gönderdiği açıklamayla yılının birinci çeyreğine ait finansal verilerini paylaştı;',
#  'turizm tedbirleri alinmis goruntu yildizli otel robotlu falan yani tatil virutik nedenlerle de yine zengine kısmet o tedbirleri kucuk isletme nasil alsin ;',
#  ' gastronomi başkenti gaziantep ;',
#  ' belgeli tesisler ön plana çıkacak ;',
#  'expedia group bugün yaptığı açıklamayla iş ortaklarına yardımcı olmak için milyon dolar lık bir kaynak ayırdığını duyurdu paketin milyon dolarlık kısmı otelciler için ayrıldı;',
#  'sondakika ukrayna ya uluslararası uçuşlar yeniden başlıyor;',
#  'işte kızıltepe de cuma namazı kılınabilecek cami ve mekan bilgileri   ;',
#  'otobüslerde ve trenlerde sosyal mesafe var uçaklarda yok ;',
#  'son dakika bakan açıkladı haziran da başlıyor;',
#  'geçtiğimiz günlerde milyon müşterinin bilgilerinin bir siber saldırıyla usulsüz olarak ele geçirildiğini duyuran easyjet verileri çalınan müşteriler tarafından dava ediliyor ;',
#  'gazipaşa yaz sezonuna hazırlanıyor;',
#  'bildiğiniz bütün kutu oyunlarını unutun çok yakında biz geliyoruz;',
#  'uçak kazalarıyla gündeme gelen boeing max ın üretimi yeniden başladı  ;',
#  'salgın süresinde nefes aldıracak ekoturizm rotası  ;',
#  'turizmciler yeni tip koronavirüs kovid normalleşme süreci kapsamında açılacak turizm sezonunda misafirlerini ağırlamayı bekliyor ;',
#  ' tüm dünyanın gözü antalya da olacaktı fırsat kaçtı  ;',
#  'kararı için türkiye deki koşullara bakacağız ;',
#  'antalya da kapalı olan oteller sezonuna hazır  ;',
#  ' verilerinin yer aldığı dünya turizm örgütü unwto mayıs barometresi açıkladı ;',
#  'antalya da sosyal mesafeli plaj uygulaması başlıyor;',
#  'haziran da yelken açacaklar ;',
#  'almanya seyahat yasağını tekrar gözden geçirecek;',
#  'gyo lar ve turizm hareketli olur mu bugün acaba ;',
#  'yasaklar her zaman zararlıdır burnumuzun dibindeki adaları göremeyenler var kaldıki ülkemiz yunanlılara göre çok ucuz çok rahatsız olsamda ticaret hareketliliği olur lehimize  ;',
#  'ispanya da temmuz dan itibaren yurt dışından gelen turistlere günlük karantina uygulanmayacak;',
#  'japonya seyahat acentelerinden tatil satın alan vatandaşlarına günlük bin yen destek vereceğini açıkladı destek dediğin böyle olur biz havanda su dövmeye devam ediyoruz turizm;',
#  'yaz ayları yaklaşırken pandemi ye karşı turizm sektöründe ne gibi tedbirler alınacak  ;',
#  'mak danışmanlık son verileri açıkladı sonuçlar çok vahim ;',
#  ' topaloğlu kemer şu anda turizm sezonuna hazır biz hem yerli hem yabancı misafirlerimizi kemer e bekliyoruz;',
#  'havayolu taşımacılığının tekrar başlamasına kısa bir süre kala turizm bakanlığı sağlık bakanlığı koordinasyonunda havaalanlarında uygulanacak covid tedbirleriyle ilgili bir sertifikasyon genelgesi yayımladı;',
#  'güney kıbrıs tatil sonrası koronavirüse yakalananların masraflarını karşılayacak;',
#  'bm dünya turizm örgütü istanbul doha ve dubai salgın sonrasında turizmde pilot projelerin lideri olacak;',
#  'çeşme turizm sezonuna hazırlandı;',
#  'turizm esnafıyım vergi afı bekliyorum hacizlerin kaldırılması bize nefes aldırır boğuluyoruzz ;',
#  'antalya belediye turizm çalgı çengiyi şişirmek için kullanmasını bilmediğiniz konuşamadığınız yazamadığınız dille ki artık dili de kullanmıyorsunuz osuruktan teyyare işleri şişireceğiz diye kıvranmayın cehalet paçalarınızdan akıyor ;',
#  'işte konyaaltı sahili nin yeni düzeni ;',
#  'berlin de turizmciler sokaklara indi ;',
#  'ekonomik zorluk içindeki alman acentalar eylemlere devam ediyor ;',
#  'turizmi canlandırmak için vatandaşlara para verecekler;',
#  'koronavirüsün dünya turizmine olumsuz etkileri devam ederken dev şirketlerden iflas ve kapatma haberleri geliyor;',
#  'ntv de lü ve li şezlonglar yalnızca ailelere verilecek diye bir haber izledim az evvel garip değil mi sizce de insanların tatile kimlerle birlikte gideceğine karışmak gibi birşey bu ya yasaklarsın ya açarsın bir gariplik var bu pandemi düzenlemelerinde;',
#  'hollandalı gezgin youtuber van dan geçerse ne olur urartular elbette bir başkadır cana yakın ve misafirperverlikte yine kendini kanıtladı;',
#  'abdullah tunçdemir den iran pazarı değerlendirmesi  ;',
#  ' genel müdürü  emitt nin tanıtım faaliyetlerine katkısını anlattı;',
#  'kızılay dan devlet hastanesine hijyen paketi desteği ;',
#  'hem iş hem dostluk pandemi döneminde rafting ve turizm geleceğine dair aa anadoluajansi çekimlerimizin ardından keyf semaverdeçay keyfi doğa ;',
#  'antalya belediye turizm kurumlar kişilerle yönetilmez akılla yönetilir akıl yoksa bugünlerin de gelip geçeceğini bilmeden havai fişek atıp çalgı çengi yapmayı bir maharet zanneder etrafında gerdan kırarsınız ;',
#  'ryanair halihazırda geniş bir bordro desteği alan lufthansa ya alman devletinin sağladığı milyar euro luk ek yardımı eleştirirken yardımın lufthansa nın almanya havacılık pazarında tekelleşmesine yol açacağını belirtti;',
#  'covid un turizm çalışanlarına en büyük etkisi ne oldu  ;',
#  'ekonomik anlamda önemli bir yeri olan turizmveotelcilik sektöründe dijital pazarlama çalışmaları nasıl olmalı    ;',
#  'mak danışmanlık son verileri açıkladı sonuçlar çok vahim ;',
#  'türkiye kıyılarına yakın yunan adalarında faaliyet gösteren yat acente işletmecileri covid salgını tedbirleri kapsamında türkiye ile kapalı tutulan deniz yollarının yeniden açılmasını istiyor  ;',
#  'açılmadan biten bir sezon ülkeye seyahat izni veren başkenti tuerkiye liste de yer almadı böylelikle çoğunluk avrupabirligi ulkelerine destek vermiş oldu ;',
#  'yaz tatili planı yapanlar dikkat havuz mu yoksa deniz mi daha güvenli prof dr ceyhan uyardı yüzerken de mesafeyi korumak lazım ;',
#  'koronavirüs sonrası otellerde neler değişti hızlı uyum sağlayan otellerdeki önlemler ;',
#  'türkiye den vazgeçemediler iptal etmek yerine ertelediler;',
#  'plajlar yeni sezona hazırlanıyor ;',
#  'sevmek için yürek sürdürmek için emek gerek ;',
#  'turizm canlansın diye japonya da tatile çıkacaklara para desteği hep yokluktan bunlar ;',
#  'turizm i açıp insanları evdekal diyorlar ama ösym de sınavlara sokuyor turizm acilmasinin sebebi turizm bakaninin otelleri kapanirsa nolcak para kazansin demi diğer esnaflara ne olucak bazi insanlar ;',
#  'ingiltere den türkiye uçak seferleri için son dakika açıklaması ;',
#  'bozcaada tutkunlarini üzecek haber ;',
#  'avrupa da turizmi kurtarma adımı karantina uygulanmayacak avrupa ülkeleri turizm sezonunu kurtarmak için seyahat koridorları kurmaya hazırlanıyor;',
#  'sezon haziran başı itibariyle başlıyor tüm partnerlerimize güzel bir sezon diliyoruz ;',
#  ' bunca yalanı nerden çıkarttınız allah aşkına dogüturkıstanlı lar dönemeyecek haldeyken allah kahretsiz çin bunların yalan yalaka larına kulak asmayın;',
#  'yeni dönem satış stratejiniz hangi yönde olacak;',
#  'nisan ayında sadece turist alabilen japonya turizm endüstrisini yeniden başlatmak için ziyaretçilerin yaptığı gezinin maliyetinin yarısına kadar finansman sağlamayı düşünüyor ;',
#  'turist rehberiyim hayat normale dönüyor ama biz boku avuçluyormuşuz gibi geliyor bakalım sonumuz ne olacak turizm;',
#  ' devletimiz her yerde herköşeyi güvenli yaşanılır hale getiriyor pkk ya yaz kış göz açtırmayan mücadele veren askerimize polisimize bakanımız teşekkürler zapsuyu üzerinde muhteşem bir proje bittiğinde gidilir;',
#  'turizm sektörü inşallah tamamen bitmez bizde zevkle giydiğimiz önlükleri atmayız ;',
#  'turizimciler hangi gerçeklikte yaşıyor karı koca iki kişi yıldız değil yıldızlı otel olsa bir hafta için tl kim odeyebiliyor abi ödeyenler elbette vardır bunu haberlere niye cikartiyorsunuz abi ;',
#  'plajda sigara içmek yasak olmuş sigara tiryakilerine en çok bu yasak koyacaktır ;',
#  'turistlere uygulanan karantina sona eriyor;',
#  'almanya ülkeye seyahat yasağını kaldırıyor ilk listede türkiye yok ;',
#  'japonya ülkeyi ziyaret eden turistlerin harcamalarının yarısını ödeyecek;',
#  'otobüs firmaları seferlere başlayacakları tarihi açıkladı;',
#  'koronovirus pandemi sonrasında negatif ve pozitif anlamda öne çıkan sektörler ;',
#  'japonya turizm ajansı ekonomiyi canlandırmak için dev bir bütçe ayrıldığını açıkladı;',
#  'dünyanın en güvenli turizm destinasyonu yunanistan gibi görünüyor ;',
#  'uluslararası hava taşımacılığı birliği iata yayınladığı analizde havayolu endüstrisinin global borcunun yıl sonuna kadar milyar dolara yükselebileceğini öngördü ;',
#  'kütahya çinili camii muhteşem görüntüsüyle sizleri bekliyor;',
#  'yabancı turistler ne zaman gelecek ruslar bu sene türkiye de tatil yapabilecek mi ;',
#  'koronavirüs sonrası maceraseverler artacak tertemiz havasıyla dogasıyla binbir rengi ile yedigöller gidilmek için en uygun yerlerden bir tanesi ;',
#  'alacaklısı adil üstündağ ın otelini basıp ölümle tehdit etti ;',
#  ' faaliyet alanı nedir emitt nasıl bir katkı sağladı gelin tüm bu soruların yanıtlarını firmanın genel müdürü atilla mert ten dinleyelim;',
#  'işte konyaaltı sahili nde uygulanacak normalleşme kuralları ;',
#  ' yılına yakın uzay turizm araçları geliştirecekler;',
#  'dünyaca ünlü sahilde sosyal mesafeli yeni düzen ;',
#  'sağlık turizminden beklentimiz çok ;',
#  'güney amerika nın en büyük havayolu firması latam bazı iştirakleriyle birlikte yeniden yapılandırma süreci gerçekleştirmek için abd de ilgili mahkemeye iflas koruma başvurusu yaptı;',
#  'acun ilicali rekorlari altüst etti dünya onu konuşuyor ;',
#  'almanya ülkeye seyahat yasağını kaldırıyor ;',
#  'konyaaltı sahilinde yeni kurallar belli oldu rastgele giriş tarihe karıştı tatilcileri ve halkı çok zorlayacak  ;',
#  ' arabası var liralık yardımın peşinden koşturuyor;',
#  'ne bayramı ne yasağı dinlediler ot biçme yüzünden silahla kavga ettiler ölü yaralı;',
#  'belediye kaş ilgili belediyelerin sosyal medya yönetimleri sıfır türkçe bilgileri zaten yok halka herhangi bir konuyu anlatma cevap verme gibi kaygıları yok zannedersiniz patagonya da patagonyalıların belediyeleri antalya ya keyif sürmek için gelmişler ;',
#  ' otellerde nasil hijyen dezenfeksiyon ve misafir ağırlama olacak ;',
#  'turizm sektörü koronavirüs sürecinde tüm paydaşlarıyla yazdı konuştu yayınladı ve önemli bir bilgi öneri havuzu oluşturdu bu süreci günümüz teknolojisi ile biraraya getirip bundan sonrasına fikir vermesi açısından değerlendirmek de iyi bir eylem olabilir ;',
#  'salgından tüm ülkelere ağır fatura ;',
#  'tabiat parkındaki şelale de koronavirüs sessizliği;',
#  'bakan kurum antalya da imara aykırı izinsiz yapı tespit edildi tümü yıkılacak;',
#  'rakiplerimiz nasıl normalleşiyor;',
#  'ahmet serdar körükçü planlarımızı mart ve sonrası için yapıyoruz;',
#  'zarina doguzov tüm çabamız vatandaşlarımızın yurt içinde tatil yapmasını sağlamak ;',
#  'ispanya temmuz itibariyle tatilcileri kabul etmeye başlayacak ;',
#  'tse den sağlikli turizm belgesi turizm bakanlığı öncülüğünde sektör paydaşlarının iş birliğiyle sağlıklı turizm belgelendirme programı hazırlandı tse tarafından denetlenecek ve sağlıklı turizm belgesi verilecek ve kuruluşlar kültür ve turizm bakanlığı web sitesinden duyurulacak;',
#  'sektör olarak enerji ve gayrımenkul girişimsermayeleri finans faktoring ile teknoloji ve turizm sektöründe hareketleri izleyelim ;',
#  ' rus turistin tatil tercihlerini açıkladı ;',
#  'bursa kalkışlı antalya olympos turumuza temmuz çarşamba gecesi ile birlikte başlıyoruz;',
#  'almanya da devlete bağlı ekonomik istikrar fonu wsf lufthansa ile ilgili kurtarma paketini onayladı paket toplamı milyar euro yu bulan özkaynak girdisi hisse ortaklığı ve kredi içeriyor;',
#  'güzel günler yakın;',
#  'turizm de yeniden açılım değerlendirmeleri için türkiye ve rakiplerin durumu ;',
#  'rusya başbakanı ndan rus vatandaşlarına çağrı yurtdışı tatillerinizden vazgeçin rusya başbakanı mishustin vatandaşlarının yaz tatillerini evlerinde geçirmeleri gerektiğini söyledi ;',
#  'salgın ve turizm sektörü üzerine ;',
#  'yeninormal de turizm endüstrisine yönelik devlet teşvikleri ön görülen ulusal ve uluslararası turizm yatırımları ve küresel bazda geliştirilecek yeni iş birlikleri ve modelleri neler olacak mayıs salı günü saat da turizm tv youtube kanalı nda ;',
#  'israil hava yolları yıl aradan sonra türkiye de uzun bir aradan sonra ilk kez bir israil hava yolları elal uçağı türkiye ye indi tourismmustsurvive ;',
#  'belçika da bulunan fly time adlı turizm firmasının logo tasarlatma tercihi bizden yana oldu kendilerine teşekkür eder iyi çalışmalar dileriz ;',
#  'restoran ve turizm işletmeleri hijyen ve sosyalmesafe kurallarına uyarak açılmaya hazırlanıyor;',
#  'herkes merak ediyordu işte böyle tatil yapacağız;',
#  'ispanya temmuz ayında kapılarını turistlere açabilir   ;',
#  'manavgat sahiline dokunma   turizm bakanı   lütfen çekin kirli ellerinizi;',
#  'restoran ve turizm işletmeleri belirlenen kurallar çerçevesinde açılacak  ;',
#  'birleşmiş milletlere bağlı dünya turizm örgütü unwto yılı verilerinin yer aldığı mayıs barometresi yayımlandı  ;',
#  'turizmciler iç sezon için hazırlıklarını ve öngörülerini açıkladı;',
#  'uzun zamandır planladığım turuzm videoları kanalımı açtım hepsi müziği görüntüsü ile özgün videolardır ;',
#  ' haziran da iç hat uçuşlarını başlatıyor  ;',
#  ' kaya demirer mehmet nane eresin pinar in katılımlarıyla turizmde yeni normalleri konuştuğumuz webinarı izlemek için turizm webinar;',
#  'almanya türkiye ye yönelik seyahat uyarısını kaldıracak mı  ;',
#  '    turizm motivasyon çalıştayında bu kez düğün festival     gastronomi turizmi stk başkanlarını bir araya getirdi ;',
#  'tarihi öneme sahip bi kaç turistik yerlerde köylüler evlerini butikotel e çevimiş ineği koyunu satmış tarım a sırtını dönüp sapı samanı unutmuştu kovid bize turizm in uzun vadede karın doyurmayacağını öğreteli ay oldu ;',
#  'otel ve plajlarda covid a karşı alınması gereken önlemler nelerdir;',
#  'borsa geleceği ılımlı mı ihracat ve turizm gelirlerinde salgın hastalığa bağlı olarak gözlenen düşüşe karşın emtia fiyatları ve ithalatın sınırlayıcı etkisiyle cari işlemler dengesinin yıl genelinde olımlı bir seyir izleyeceğini öngörüyorum ;',
#  'yıl turizm bakanlığı turistler için finlandiya dan tuvalet kağıtı ithal etti;',
#  'çavuşoğlu rusya almanya ve çeşitli ülkelerden turistleri charter uçuşlarla getirebiliriz;',
#  'bu turizm sezonu böyle devam edecek;',
#  'ulaştırma ve altyapı bakanı adil karaismailoğlu demiryolları ulaşımında normalleşme sürecinin başlatılacağını belirterek sürecin tedbirlerle birlikte yürütüleceğini söyledi turizm ulastırma yeninormal;',
#  'antalya türkiye belediye turizm yol artık yılan herkese dokunuyor herkesin canını yakacak allah a olan samimiyetimizi sorgulayıp yeniden tesis etmek zorundayız islam kuru bir bayram tebriği değildir allah adına yaşamasını öğrenmeliyiz ;',
#  'türkiye dünyada en çok ziyaretçi ağırlayan kaçıncı ülkesi ;',
#  'ülkede gününü yaşadığımız salgında turizm bakanlığı turizm işletmelerine pandemiyle alakalı standartları hala yayınlamış bildirmiş değil buna rağmen insanlara turizm şu zaman başlar diyerek gaz veriyorlar bu yaz otel tatili yapanın aklına şaşarım;',
#  'ramazan bayramınız mübarek olsun sağlıklı güzel bayramlar dileriz ;',
#  'turizm merkezlerinin plaj ve sahilleri sessiz kaldı ;',
#  'covid ile mücadelede tüm önlemlerimizi alıyoruz yakında güzel haberler paylaşacağız ;',
#  'turizm deyince aklıma gelen güzel seyahatler canım italya amalfi kıyısı tekrar bu kalabalıkları görecek mi nasıl sessiz bir cumartesi evdekal alarak geçiriyoruz elbet ;',
#  'sanatçılar tercih ediyordu ünlü otel corona nedeniyle iflas etti  ;',
#  'turizm  gelirlerinde iki basamak yükseldi dünya turizm örgütü yılı verilerine göre türkiye dünyanın en çok ziyaretçi ağırlayan ncı ülkesi oldu turizm gelirlerinde ise iki basamak daha yükselerek üncü sıraya yerleşti;',
#  'dışişleribakanı mevlütçavuşoğlu dan turizm açıklaması ülkemizi bilen herkes gelmek istiyor ;',
#  'cumhurbaşkanlığı sözcüsü ibrahim kalın turizm sektörünün haziran ortasında açılmasını bekliyoruz;',
#  'kıbrıs rum kesimi havaalanları yeniden açıldığında rus turistleri yasaklayacak;',
#  ' yılında kurulmuş olan araç kiralama şirketi hertz covid salgınının yol açtığı ekonomik daralma nedeniyle amerika birleşik devletleri nde ilgili mahkemeye iflas koruma başvurusu yaptı ;',
#  'hastalığa tekrar kavuşmak için ülkeler arasındaki yarış başlıyor sanki ;',
#  've spa araştırmaları enstitüsü pazar araştırma başkanı ulf sonntag tan çarpıcı tespitler ;',
#  'arefe geldi bayram geliyor derken geldi çattı berber kuaför ve konfeksiyon sahiplerinin gazı alındığına göre bu ülkenin gerçek ekonomisini oluşturan turizm sektörüne sıra gelmiştir;',
#  'alman hükümeti milyar eura ile lufthansayı kurtardı;',
#  'kültür ve turizm bakanlığı nisan ayı yabancı ziyaretçi istatistiklerini açıkladı;',
#  'gez ceylan bu dağlarda ;',
#  'koronaya iyi gelen ilaç ölüm riskini de arttırıyor;',
#  'antalya belediye turizm de başarı bir otel sahibi veya yöneticisine bağlı değil deniz suyu sıcaklığına bağlı otel sahibi ve yöneticisi için ne acı bir durum ikisi de aslında hiç bu sektörde bir hiç olarak varlar ve ilginçtir ki var olmak için de çalışmıyorlar ;',
#  'türsab korona virüs salgını ardından uygulanacak yeni normal sürecini daha iyi anlamak ve sürdürülebilir çözüm önerileri geliştirmek amacıyla bir rapor hazırladı;',
#  'simav ilçemize bağlı olan gölcük yaylası sahip olduğu doğal güzelliklerle sizleri bekliyor plateau nature tourism welcomesyou ;',
#  'bu yıl mavi bayraklı plaj sayıları antalya da ya muğla da e izmir de ye aydın da e balıkesir de e istanbul da ye samsun da da e yükseldi van ise denize kıyısı olmamasına rağmen mavi bayraklı plaja sahip olan tek il olarak kayda geçti;',
#  'türkiye mavi bayrak ta ispanya ve yunanistan ın ardından dünyanın en çok mavi bayraklı üncü ülkesi olan türkiye nin ödüllü plaj sayısı bu yıl artarak ya yükseldi ;',
#  'dünya genelinde turizm ve seyahat sektöründe milyon insan istihdam edilir ve bu sektörün küresel gsyih ya yüzde luk katkısı vardır bu sektörün pandemiden sonra nasıl bir yol izleyeceği bütün dünyada merak konusu;',
#  'unesco dünya mirası listesindeki nemrut dağı turizme açılıyor;',
#  'rus turistlerin gelişi için turizm bakanı ersoy temmuz u ruslar ağustos u işaret etti;',
#  'erciyes e bir otel zinciri daha mı geliyor ;',
#  'turizm çalışma grubu olarak duayen turizmci dr cem kınay ile covid sonrası yeni turizm trendlerini konuştuk;',
#  'mehmet nuri ersoy tatil amaçlı özel izin belgesi oluşturulacak  ;',
#  'merkezi ingiltere de bulunan popüler tur operatörü ve havayolu jet bugün yaptığı duyuruyla yaz programına temmuz da başlayacağını duyurdu;',
#  'sağlık bakanı nelutataru işler düşündüğümüz gibi yolunda giderse haziran da terasları ve haziran dan itibaren de plajları açmayı düşünüyoruz romanya romen turizm karadeniz kostence ;',
#  'bu yaz tatilde böylemi;',
#  ' bin yıllık tarihi maraş kalesi hizmete açılıyor ;',
#  'sevgide özgürsünüz;',
#  'dünya sağlık örgütü mart ta pandemi ilanı yaptı dünya turizm örgütü turist sayısının ile arası düşeceğini öngördü  ;',
#  'burası japonya olsa beğenir diniz dimi ama burası türkiye;',
#  'uluslararası mavi bayrak jürisi yılı mavi bayrak ödüllerini açıkladı bu yıl türkiye de plaj marina ve bireysel yatta mavi bayrak dalgalanacak;',
#  'avrupa dan türkiye ye karayolu ile tatile gidecekler için sılayolu nda son durum ;',
#  'koronavirüs etkisiyle nisan ayında ülkemize gelen yabancı ziyaretçi sayısı azaldı tüik in turist başına ortalama harcama verisi dikkate alındığında bu düşüş turizm gelirlerinde sadece nisan ayında yaklaşık milyar dolarlık bir gerilemeye işaret ediyor ;',
#  'bozova da turizme kazandırılması gereken yerler;',
#  'ihtiyaç sahiplerine bin koli yardımı gönderdi ;',
#  'bursa turizmde pandemi sonrasına hazırlanıyor;',
#  'katılımcılarımız arasında yer alan akra hotel satış sorumlusu meltem aydın emitt yi değerlendirdi tüm firmalar kendini emitt e tanıtma imkanı buluyor bu anlamdai açısından emitt in önemli olduğunu düşünüyorum ;',
#  'turizmciler yeni sezona yüksek fiyatlarla hazırlanıyor;',
#  'ulaştırma ve altyapı bakanı havalimanlarına ilişkin bir sertifikasyon programı yaptıklarını ve söz konusu sertifikasyon programı ile tüm havalimanlarının tekrar düzenleneceğini açıkladı;',
#  'kültür ve turizm bakanlığı nca açıklanan turizm istatistiklerine göre nisan ayında yabancı ziyaretçi sayısı geçtiğimiz yılın aynı ayına göre geriledi nisan da türkiye ye sadece yabancı turist geldi ;',
#  'turizm sektörü için önemli açiklama  ;',
#  ' turizm bakanı  telekonferansta turizm sektörüne ilişkin değerlendirmelerde bulundu bakan ersoy bayramdan sonra istanbul dan çıkışlar için tatil amaçlı özel izin belgesi oluşturulacak ;',
#  'litvanya nın başkenti vilnius ta turizmi ve esnafı hareketlendirmek adına alınan karar bence bizde de incelenmeli ;',
#  'covid gölgesinde yaz tatili turizm sezonu ne zaman açılacak beklentiler neler;',
#  'birlik üyelerimizle yaptığımız pandemi sürecinde turizm konulu oturumda acentalarimizin yaşadığı sıkıntılar ve devletten bekledikleri destekler uygulamalara yönelik genelgeler konuşuldu ;',
#  'hollanda seyahat yasaklarını gevşetecek listede türkiye yok;',
#  'dünya mevleviliğinin ikinci adresi olan afyonkarahisar da frigya vadileri arasında yer alan emre gölü buz tuttu buz tutan gölün üzerinde semazen bahadır okyar sema gösterisi yaptı çağrı selek in görüntülediği sema dikkat;',
#  'özellikle yılından beri turizm tam bir kumar gibi sene e veriyor sene elindekini alıp götürüyor ;',
#  'urfa da yol tepkisi konu bakanlığa iletildi ;',
#  ' haziran itibari ile siz değerli ziyaretçilerini bekliyor ;',
#  'türkiye de ikinci güvenli turizm belgesi alanya ya gitti ;',
#  'güvenli turizm belgesi dönemi başladı ;',
#  ' air de uçuşlarına başlıyor ve biz seyahat acenta larına çok güzel bir bilgilendirme göndermişler umarım en kısa zamanda yeninormal ile turizm eski güzel günlerine geri döner ;',
#  'koronavirüs salgını sonrasında turizm ve bağlantılı sektörler nasıl etkilenecek ;',
#  'alanya daki esnaf umduğunu bulamiyor ;',
#  'korona virüsün giremediği turizm bölgesine girişte  ;',
#  'türk hava yolları haziran da bazı yurtdışı seferlerine yeniden başlayacak bu ülkelerden bir tanesi hollanda ;',
#  'rusya nın bayrak taşıyıcı havayolu firması aeroflot bugün yılının ilk üç ayına ait finansal verilerini açıkladı ;',
#  'ekonomiye milyar liralık sıcak para ;',
#  'umarım bütçesi ne olursa olsun her işletme personeli için de gereken özeni gösteriyordur neticede her şeyin başı sağlık tüm turizmci otelci kardeşlerime iyi sezonlar ;',
#  'vali karaloğlu en kötü senaryo milyon insan antalya ;',
#  'türk hava yolları genel müdürü bilal ekşi thy nin haziran tarihinden itibaren istanbul dan yapacağı yurtiçi uçuşların programını duyurdu ;',
#  'bütün direklerde tek bayrak turizm ;',
#  'xturzm fibo ü güçlü kırarak ralliye girdi seyahat yasağınında kalması ile daralan toplumun büyük tatil iştahı turizm endeksine güçlü alış getirerek büyük fincan kulp formasyonunu çalıştırdı. büyük düşeni kıran tektu favorim olmakla birlikte ;',
#  'ziraat bankası halkbank ve vakıflar bankası konut taşıt ve yerli üretime yönelik tüketici kredilerinin yanında olarak turizmi desteklemek için tatil destek kredisi isimli bir kredi paketi programı başlattılar ;',
#  'hes kodu hakkında bilgilendirme ;',
#  'macaristan ın bölgelerini tanıtmaya devam ediyoruz marianna nyitrai bize doğasıyla herkesi büyüleyen ve müzikteki yeteneğiyle ön plana çıkan s rköz u anlatıyor ;',
#  'camimizi izlenmeye deger tarihten günümüze süregelen yapıtlar arasında yer alan namazgahını görüntüledik ;',
#  'senelerdir kanayan bir yara bu çok mağdur arkadaşlarım var lütfen retweet yapalım hocamızın sesini duyuralım arkadaşlar  tckültürveturizmbakanlığı ;',
#  'salda gölü ziyarete açıldı;',
#  ' topaloğlu kemer şu anda turizm sezonuna hazır biz hem yerli hem yabancı misafirlerimizi kemer e bekliyoruz ;',
#  'yeni bir mevsim yeni bir ay yeni bir gün sağlıklı huzurlu ve hayırlı olur inşallah ;',
#  'milli gazete nuri ersoy u manşetine taşıdı bu bizim kültürümüz değil kültürsüz bakan;',
#  'malatya mızın gastronomi merkezi olacak  center da bugün yeşilyurt belediye başkanımız sn mehmet çınar ile birlikte yeşilyurt kaymakamımız sn turgay gülenç i ağırladık;',
#  'adalara giriş çıkış kısıtlaması sona erdi vatandaşlar erkenden yola çıktı;',
#  'neuschwanstein kalesi neuschwanstein kalesi almanya nın bavyera eyaletine bağlı füssen yakınlarındaki hohenschwangau kasabası yakınında bulunan sarp bir tepeye kurulmuş olan katlı yüzyıl neo romantizm mimari stiliyle yapılan kaledir ;',
#  'türkiye turizmini yükseltecek öneriler ;',
#  'atlıoğlu turizm sektörü ayakta tutulmalıdır;',
#  ' hotelbeds bugün çalışanlarına yaptığı açıklamada covid krizi nedeniyle şirketin dünya genelindeki çalışanlarından sini azaltacağını duyurdu;',
#  'beş yıldızlı oteller çardakları kurmaya başladı ;',
#  'seyahat sektöründen ciddi reklam geliri elden eden google otelcilerin pazarlama maliyetlerini daha etkili bir şekilde yönetebilmeleri için yeni bir modeli devreye aldı ;',
#  'bundan daha komik birşey de duymamıştım bu kadar önlem altında hafta tatil yapmaya çalışacaksın tatilin eziyet olacak bir de sene sonra hala bu tatilin parasını ödüyor olacaksın gitmeyin arkadaş bu sene de tatile gitmeyin;',
#  'dünyanın bir çok ülkesinde normalleşme ile turizm sektöründe de hazırlıklara başlandı ukrayna dan ise vatandaşlara türkiye salgına karşı güvenli bir ülke tatil için en iyi seçenek çağrısı geldi ;',
#  'türsab turizm ulaşımında covid için alınan önlemlerle ilgili bir video hazırladı turizm ulaşımında covid için hangi önlemler alındı ;',
#  'tatilin efsane hali haziran itibari ile kapılarını açıyor ;',
#  'turizm sektörü tatil kredisinden memnun ;',
#  'tatil kredisi seyahat acentelerinden tatil paketi satın alacak olanlara bin tl ye kadar ay ödemesiz ve ay vadeli finansman imkanı sunulacak turizm hadi hayırlı olsun;',
#  'su altı turizminin merkezi korona girmeyen ilçe misafirlerini bekliyor ;',
#  'cruise tatilleri seyahat ve turizm endüstrisinde pandemisinden en büyük darbe alan segmentlerden biri oldu seferlerine yeniden başlamak için operasyonlarına hız veren kruvaziyer turizminin büyük çoğunluğu hedefliyor;',
#  'sahillerinde sosyal mesafeli deniz ve güneş keyfi dönemi ;',
#  'andırın belediye başkanı ahmet doğan tarihi eserlerimizi korumalarını sağlamak ve turizme kazandırmak istiyoruzhaziran pazartesi ;',
#  ' kilis in mevcut durumu imalat sanayi tarım hayvancılık turizm ve ticaret alanlarında hem sosyal hem de ekonomik açıdan ele alındığı kilis ekonomi strateji belgesi kalkınma kütüphanesinde yayında ;',
# ...
#  'kemençe eşliğinde piknik sezonu başladı ;',
#  'havuzlar için önlemler alınmış ana haberde diyor ki orta boyuttaki bir site havuzu göstererek bu boyutta bir havuza ten fazla kişi girmeyecek havuzun sırası duşun sırası nasıl olacak onu anlatamıyor ;',
#  '  konsepti kolaylık dinamizm konfor geniş erişim imkanları interaktif lobisi işlevsel ve şık odaları ile günümüz gezginlerinin odak noktası olarak planlandı  ;',
#  ' dağlarca çağlar bugün saat da de nin sunduğu üst düzey programı nın canlı yayın konuğu olacak ;',
#  'antalya belediye turizm insanlar değerli olmayı unuttular önemli olmaya çalışıyorlar ;',
#  'antalya belediye turizm başarı yalan söylemek zorunda kalmadan yaşayabilmektir ;',
#  'rize normalleşme süreci ile birlikte turizme hazır   ;',
#  ' bakan ersoy ikinci dalgadan bahsediliyor bana göre bunun ikinci dalgası ekonomi  ;',
#  'burası tarihin sıfır noktası göbeklitepe ;',
#  'gücün güvenle kalitenin konforla birleştiği yer viptravel  ;',
#  ' kapalicarsi esnafı kendilerine destek vermeyen akp için ne düşünüyor  ;',
#  'dün seyahat rotamdaki oluşabilecek teknik zorunluluklardan dolayı bugüne ertelediğimiz sohbetimize bekliyoruz t ;',
#  'bakan ersoy btso turizm konseyi üyeleriyle bir araya geldi  ;',
#  'sigacik yasaksiz gunlerde bile hala yasakliymis gibi ama gordugunuz anda sizi icine ceken buyulu bir masal diyari gibi şu net istanbul sehirlerin krali ise izmir kesinlikle sehirlerin kralicesi  ;',
#  'tesis açışlarının hepsini erkene alacağız ;',
#  'rize eski valisi renk projesinin mimarı yazıcı buçuk milyonluk turizm şehrini yönetecek  ;',
#  'bakan ersoy önceliğimiz bütün ülkelerle hava trafiğini başlatmak ;',
#  'alman turizm puzzle ı parça istedigi yere seyahat vatandaşlık hakkıdır ab içinde seyahat serbesttir ab dışına sehayat uyarısı agt a uzatılmıştır seyahat uyarısı bir uyarıdır almanya dışına gidenler geri getirilmeyecektir ;',
#  '  ersoy temmuz itibarıyla tesislerin hepsinin açılacağını düşünüyorum ;',
#  'normalleşme sürecindeyiz madem niye türkiyeye uçuşlar normalleşmiyor  ;',
#  'yurtdışı uçuşlar ne zaman başlıyor hangi ülkelere uçuş yapılabilir avrupa türk vatandaşlarını kabul edecek mi hepsinin yanıtı kanalımızda  ;',
#  'bu durum bir nevi ihanet vesikasi ;',
#  'geçtiğimiz günlerde google maps duyurduğu yeni özellikle covid ile ilgili önemli bilgileri haritadan kullanıcılarına sunmaya başladı  ;',
#  'sıkıntılı süreci atlatmaya gayret eden herkesin işi gücü rast gelsin zor günlerde hayırlı olsun ya da hayırlı işler ziyaretleri çok daha anlamlı olmalı  ;',
#  'kültür ve turizm bakanı ersoy galata kulesi nin içindeki kapalı alanı boşaltıp müze haline getiriyoruz   ;',
#  'kktc de mart tarihinden önce ülke içinde bir seyahat acentasından yılı için satın alınmış olan tur paketlerini kullanamayan kişiler tur paket tarihlerini ileri bir tarihe erteleyebilecekler  ;',
#  ' ab dış sınırları temmuz dan itibaren kademeli olarak açacak  ;',
#  'yurt dışından gelenlere test ve karantina uygulaması olacak mı bakan koca o soruya yanıt verdi ;',
#  'turizm için kötü haber almanya ab dışındaki ülkelere seyahat uyarısını ağustos sonuna kadar uzattı ;',
#  'avrupa dan kötü haber seyahat uyarıları uzatılıyor   ;',
#  'iç turizm canlandı ama vaka sayısında beklenmedik artış  ;',
#  ' gönüllü tanitim elçisi oldu depremde gönüllerde daha da büyüdü klasik valilik yapmadi pandemide türkiye ye örnek oldu öbür yanda sakarya elaziğ i yatirim cenneti yapti  ;',
#  'antalya belediye turizm yıl katıksız tüm belediyelere bakın durumu ve günü kurtarmak için alt yapıyla uğraşıyorlardır halkın nafakasını plansız programsız toprağa ve herkesin kendine göre yandaşına gömüyorlardır bir kişi de sormaz mı bu şehir ve ilçeler dün mü kuruldu ;',
#  'alanya nın oteli ilk e girdi  ;',
#  'ben turizm acentesi olsam kendi logomun telefonumun basılı olduğu maske dağıtırdım turda misafirlerime daha epey sürecek gibi bu maskeli balo  ;',
#  'vali çeber rize deki vaka durumu hakkında konuştu ;',
#  'mutfak mirası alanya da sosyal tanıtımlar sürüyor  ;',
#  'bodrum da bazı işletmelerin sahile beyaz kum döktüğü iddiası  ;',
#  'bekir yılmaz dan bodrum a günde bin araç girdiği iddiasına açıklama  ;',
#  'turizm sektörü aldığı önlemler ve başlatılan güvenli turizm sertifikasyon programı ile yerli ve yabancı konuklarını ağırlamaya hazırlanıyor ;',
#  'almanya nın ağustos a kadar avrupa birliği üyesi olmayan ülkelere gidiş ve gelişlerle ilgili seyahat uyarısını uzatması bekleniyor  ;',
#  'alanya daki esnaf isyan etti ;',
#  'güvenli turizmin adresi  çeşme;',
#  'ardahan ın posof ilçesinde peribacaları görünümlü oluşumlar ile dikkati çeken halk arasında hıram olarak adlandırılan vadi turizme kazandırılıyor ;',
#  ' i ogm ye bağlı eşsiz ekoturizm rotası ile nefes alacaksınız  ;',
#  'bddk turizm harcamalarında taksit sınırını aya yükseltti ;',
#  'almanya avrupa birliği üyesi olmayan ülkelere seyahat uyarılarını ağustos a kadar uzatmayı planlıyormuş turizm de yaşanacak böyle bir sıktıntı antalya başta olmak turizm şehirlerimizi ve türkiye ekonomisini ciddi biçimde etkileyecek ;',
#  'karacabey in yazlık tatil bölgeleri yeni normalde turizmin merkezi olmaya aday ;',
#  'bu korona virüs salgınıyla turizm sektörce yalnızlığın ve sessizliğin simgesi haline gelecektir insanlar sosyal mesafe yakınlığından uzak bir tatil şekli oluşturmaya mecbur kalacaklardır  ;',
#  ' turizm canlandırılmaya çalışılırken yerli turist sistemi kurtarabilecek mi ve ab içindeki koridorlara dahil olmadan milyar dolarlık gelirin yüzde kaçına ulaşabileceğiz  ;',
#  'mudanya belediye başkanı hayri türkyılmaz ilçe esnafının sorununu çözmek için her türlü desteği vermeye hazır olduklarını söyledi  ;',
#  'bae korona dan sonra dünya turizm haritasında en çok talep gören ülkeler arasındadır ;',
#  'turizm sektörü eski günlerini arıyor;',
#  'birleşik krallık ın önemli havayolu ve tur operatörlerinden jet uçuş ve tatil operasyonlarına başlayacağı tarihi bir defa daha erteleyerek temmuz u işaret etti ;',
#  ' tunceli ye huzuru getiren vali olarak tanınan yeni ordu valisi tuncay sonal munzur çayı nı dünyaya tanıttı vali sonal ın turizme tanıtıma sosyal faaliyetlere ve spora büyük destek olduğu ifade ediliyor   ;',
#  'corona sonrasi turizm bolgelerinde alinan tedbirler sahiller turizme hazir  ;',
#  '  yeni güne ve kalan ömre takip etmeyi unutmayın lütfen    ;',
#  'araştirma turizm için yeni küresel ilkeler keşfedin  ;',
#  ' corona sürecinde tatil konusundaki yaklaşımları ve turizm sektörünü inceliyor   ;',
#  '  bölümünde corona sürecinde tatil konusundaki yaklaşımları ve turizm sektörünü inceliyor  ;',
#  'cennet cehennem doğa harikası asansör yapmak nedir hangi zengin yandaşınızı saha da zengin ettiniz  ;',
#  'kültür ve turizm bakanlığı turist rehberlerine ilişkin genelge yayımladı  ;',
#  'projemizin detayları şekillendikçe sizlerle paylaşmayı da ihmal etmeyeceğiz ayrıca anlamlı açılış hediyeleri içinde çok teşekkür ederiz  ;',
#  'otobüsler daha sağlıklı çifte standart uygulayan yetkilileri kınıyoruz bu kadarda tarafinizi belli etmeyin ya kardesim c ;',
#  'havayolları seyahat acenteleri ve konaklama ile ilgili yurt içine ilişkin harcamalarda taksit sayısı aydan aya çıkarıldı  ;',
#  'taşkızak tersanesi mesela muhteşem müze alanı gençleri gemi inşa alanına yönlendirmek için kullanılabilir gerçi eğitimi verip yetiştirip yurt dışına gönderiyoruz o ayrı konu turizm bakanlığı bana fırsat ver bu gece turizme taktım ;',
#  'yurt içi seyahatlerde milyar milyon bin tl harcandı ;',
#  'almanya bizi konuşuyor  ;',
#  ' center avm il den dm den sipariş verebilirsiniz  ;',
#  'turizm de taksit sayısı artırıldı   ;',
#  ' turizm çalışanlarının yüzde i işsiz kalacak  ;',
#  'turizmcilerden başbakanlık önünde şezlonglu şemsiyeli eylem ;',
#  'saruhanlı daki doğa harikası göl turizme açılacak  ;',
#  'türkiye ye seyahate ilişkin almanya dan açıklama ;',
#  'osmangazi fetih müzesi nde hasret bitiyor ;',
#  'seyahat acenteleri birliği nin yarın yapacağı eyleme otelciler birliği nden destek ;',
#  'türkiye de butik oteller resort lara karşı  ;',
#  'rum hükümeti turizm sektörünü canlandırmak için uluslararası seferberlik başlattı ;',
#  'doğu akdeniz ve libya üzerine görüşme de turizm in adı geçmedi anlaşılan merkel e almanlar türkiye yi özledi ile başlayan cümleler kurulamadan hava da asılı kaldı belli ;',
#  'alman seyehat acentaları birliği seyahat uyarısının turizm sektörünü batıracağını açıkladı ;',
#  ' da maske zorunluluğu olmalıdır turizm kentiyiz ve malum yaz mevsimi millet geliyor acilen karar alınmalıdır ya maskesiz girilmez ;',
#  'turizm okumaya karar verdim anlık ;',
#  'covid sonrası turizm sektörünün geleceğini yarın arasında mediacatlive buluşmasında konuşacağız bekleriz hemen kayıt olun  ;',
#  'merkezi ispanya nın palma şehrinde bulunan seyahat toptancısı hotelbeds bugün api uygulamasında yaptığı bazı yenilikleri ve yenilenen api arayüzünü tanıttı  ;',
#  'hilton zinciri bugün yaptığı açıklamayla covid krizi nedeniyle çalışanla yollarını ayıracağını duyurdu  ;',
#  ' maral dünya da eşi benzeri olmayan bir yapı odalı dubleks tripleks yapıya sahip amfi tiyatro ve doğal akustik ses özelliği ile eşsiz ve mükemmel bir baş yapıt hasan bey yüreğinize sağlık  ;',
#  'bodrum yat limanına haziran itibariyle elektrik ve su verildi  ;',
#  'inönü ilçesinde prehistorik çağlardan tarih öncesi günümüze kadar gelen ve turizm açısından büyük öneme sahip tarihi mağaralar drone ile havadan görüntülendi  ;',
#  'antalya nın falez plajları açıldı ;',
#  'mice turizminin liderleri anlatıyor ;',
#  'covid salgını sebebi ile mart tan bu yana uçuşlara ara veren onur air esnetilen seyahat kısıtlamaları neticesinde haziran itibariyle tekrar seferlerine başlıyor  ;',
#  'bodrum da oteller yerli turistle hareketlendi  ;',
#  'onur air haftanın günü bodrum a uçacak  ;',
#  'turizm sektörü pandemi etkisinden kurtulmanın yollarını arıyor ;',
#  'ekonomisinin lokomotifidir turizm işletmesilerine ve turizm calışanlarina destek verilmeli yoksa kapanacak olan tesislerle birlikte yetişmiş kalifiye turizmci baska alanlara kayacak yeniden kalifiye turizm elemani yetiştirmek yılımızı alır  ;',
#  'dünyada en yüksek turizm gelirine sahip ülke rakamları milyar dolar abd  ;',
#  ' tui group yaz sezonu için yeni planlarını açıkladı ;',
#  'adana da gezilecek en güzel yerler ;',
#  'turizmcilerden hükümete türkiye baskısı  ;',
#  'artık siparişler qr kodla veriliyor ;',
#  'artvin turizmine mutlaka kazandırılması gereken bir yapıt tam yaşında dile kolay yüz yıl ikiyüzyıl değil asır sümela manastırına eş değer  ;',
#  'yerli buğdayda üretim üç yılda tonu aştı ;',
#  'sınırların açilmasiyla bir günde bulgaristanli yunanistan a akin etti  ;',
#  'düğünler için yeni yasaklar yolda;',
#  'gizli bir cennet olan sakaryabaşı nın akvaryum berraklığındaki sularına davet ediyoruz yaz kış su sıcaklığının c olduğu metreye kadar dalış imkanı sunan doğa harikası kaynaklarımızda buluşmak dileği ile  ;',
#  ' da çekmiştim yine yeni yeniden meydan kargalara kaldı ;',
#  'bakan ersoy un çeşme projesi teması  ;',
#  'en çok turistin geldiği ülkeden seyahatlerin muhtemel en erken başlama tarihleri   temmuz ayı için ikna çalışmaları devam ediyor ;',
#  'eyfel kulesi yeniden açılıyor  ;',
#  'turist sayısı yüzde azaldı  ;',
#  ' turizm başkenti antalya kemer de taşkın riski azaltıldı sarıören taşkın koruma kısım projesi ile estetik emniyet ve ekonomi ön plana çıkartılarak hem bölgenin taşkın riski azaltılmış hem de turizm bölgesi olan ilçe estetik bir görünüme kavuşturulmuştur ;',
#  ' italya nın venedik şehri kapılarını yeniden turistlere açtı ;',
#  'halfeti ye giden turistlere sürpriz yavaşlayın  ;',
#  'pandemi hastalarına dilde destek ;',
#  'mardin de bir ay boyunca yasaklandı ;',
#  'almanya nın seyahat yasağına karşı eylemler başlıyor sırada dava var ;',
#  ' temmuz tarihinden itibaren kuzey kıbrıs türk cumhuriyeti ne giriş yapacak türk vatandaşlarından son saat içinde yapılan ve sonucu negatif olan pcr testi istenecek   ;',
#  ' dönüm buğday yangında küle döndü ;',
#  'türkiye gaziler ve şehit aileleri vakfından şehit ailelerine ziyaret ;',
#  ' iç turizmi canlandırmak için vatandaşlarına adet ücretsiz tren bileti verecek  ;',
#  'bugün tokat ın turizmdeki yerini konuşuyoruz ;',
#  'dünyaca ünlü turizm merkezi uzungöl ün çevresi düzenlenecek ;',
#  'sezona geç başlayan turizm sektörü önceliği içeriye verdi iç turizmi hareketlendirmek için kültür ve turizm bakanlığı nca verilen sağlıklı turizm sertifikasyonu nu şu ana kadar otel restoran almaya hak kazandı ;',
#  'turist sayısı yüzde azaldı;',
#  'nasıl güzel bir bilsen karadeniz    ;',
#  'türkiye sağlık turizminde geçen yıl milyon turist ağırladı turistlerin bıraktığı döviz ise milyar dolara ulaştı türkiye turist başına geliri kat artırdığı için sektörde ataklarını sürdürüyor  ;',
#  'lezzetlerini tatmak kültürünü keşfetmek güzelim çukurova insanıyla tanışmak ve harika manzaralar görmek için osmaniyeye git ;',
#  'kentimiz bir konaklama tesisi daha kazandı bugün açılışı yapılan işletmede sayın valimiz aziz yildirim tesisi inceleleyerek işletme sahibine hayırlı olsun temennilerinde bulunmuştur bizde il kültür ve turizm müdürlüğü olarak işletmenize turizm sektöründe başarılar dileriz ;',
#  'sayın merkel türkiye böyle bir kararı kesinlikle hak etmedi ;',
#  'seyahat uyarilari hakkinda merak edilen sorular ve cevaplari tatil için gidilen ülkede sınırlar aniden kapatılırsa ne olacak seyahat uyarısı yapılan bir ülkeye yine de gitmek mümkün mü ;',
#  'metro turizm halka arz olacak ;',
#  'istanbul kültür sanat vakfı genel müdürü görgün taner ileyeni dönemde kültür sanat etkinliklerinin içeriklerini canlı yayında konuşacağız ;',
#  'uzungöl projesinin ilk etabı için haziran da ihaleye çıkılıyor ;',
#  'belçika da iç turizmi ve ekonomiyi canlandırmak için bütün vatandaşlara temmuz dan itibaren ücretsiz tren bileti verilecek   ;',
#  'iç turizmde hareketlilik başlıyor aktob başkanı erkan yağcı iç turizmdeki hareketliliğin başladığını ve rezervasyonların geldiğini belirterek tesisini açan otellerimiz var ancak asıl otel açılışları haziran dan sonra yoğunlaşacak dedi ;',
#  'emlak satış istatistikleri açıklandı mardin de son bir ayda rekor kırıldı  ;',
#  'metro holding bünyesindeki metro organizasyon ve ticaret a ş nin halka arz işlemlerine başlaması yönünde karar alındı  ;',
#  'turizmin yel değirmenleri turizm sektörünün don kişot ları yel değirmenlerine karşı turizm kavramlarının geniş bir açıdan güzel bir değerlendirmesi   ;',
#  'tip fakültesine giden yolda üniversite sağlık programlarını güçlendiriyor ;',
#  'turizm bu ülkenin bel kemiği olmaya devam edecek   ;',
#  'korona ya yakalansa solunum cihazı ve maske bolluğu içerisinde ücretsiz tedavi olabileceği tek ülke türkiye olmasına rağmen nazlanan turistler de gelmezlerse gelmesinler canım  ;',
#  'ilk tercihleri yine türkiye temmuzdan itibaren geliyorlar   ;',
#  'tatilini kendin seç ve planla biz sadece hediye edelim kura yok kupon yok ödeme hiç yok ;',
#  'aşı veya kesin çözüm sunan ilaçlar üretilmediği sürece havacılık ve turizm sektörünü çok çetrefilli bir süreç bekliyor aksi takdirde geleneksel anlayış ve pratiklerin dışındaki bir modele doğru tamamiyle transformasyon ve restorasyona uğraması elzem ;',
#  'fotoğraflarla saklıkapı ve karaleylek kanyonu ;',
#  'turizm cileri kurtarmak adina yaptiginiz erken normallesme adimlarinin sonucundan memnun musunuz gunluk vaka sayisi lere dayandi yine ;',
#  'türkiye coronavirüs e karşı ülkeye sağlık yardımları uluslararası ilaç geliştirme çalışmaları gibi önemli gelişmeler kaydetti dışarıdan hiç bir yardıma ihtiyaç duymadan bunları gerçekleştirdi ve türkiye şu anda turizm de her türlü imkanı sağlamanın gayesi içerisindedir ;',
#  'alanya da turizm esnafı çaresizlik içinde hükümet sessiz yetkili bakanlar sessiz milletvekilleri oda başkanları sessiz haziran de icra daireleri açılıyor alacaklılar tetikte turizm çalışanlarına ve turizm esnaflarına nefes aldıracak acil bir çözüm bulunulmalı   ;',
#  'hani siz turizm uğruna heba etiniz ya gençleri size söz veriyorum siz bu sınavları iptal edin ay boyunca tatil yapmayan olsun ;',
#  'mersin de tarihi ve doğal güzellikler havadan görüntülendi ;',
#  'balıklıgöl de altın renginde balık görüldü ;',
#  ...]

# %%
d= list()
for i in range(orders):
                    c= analysis(Tweet[i])
                    #a = c[0]['label']
                    a = code_to_label[c[0]['label']]
                    #d =np.append(a)
                    d.append(a)

# %%
d
df_Tweets["Tweets_duygu"]= pd.DataFrame(d)
#df_Tweetler["Tweets_duygu"]=df_Tweetler["Tweets"].map(lambda x: "".join(d))

# %%
len(d)
# Out:
# 2017

# %%
df_Tweets
# Out:
#                                                  Tweets Tweets_duygu
# 0      sayın cumhurbaşkanım turizm için ertelendiğin...      negatif
# 1      bir kere ya bir kere gencinizi dinleyin biz y...      pozitif
# 2     o kadar çok mağduruz ki neye üzüleceğime şaşır...      negatif
# 3      bu sınav tarihini değiştirirken pedaloglara v...      negatif
# 4           turizm yılı gençlik geleceğinizi kurtarır ;      negatif
# ...                                                 ...          ...
# 3084                                                  ;          NaN
# 3085                                                  ;          NaN
# 3086                                                  ;          NaN
# 3087                                                  ;          NaN
# 3088                                                 ;           NaN
#
# [3089 rows x 2 columns]
